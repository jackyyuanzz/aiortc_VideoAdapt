# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
rate_hist = np.loadtxt('bitrate_record.txt',delimiter=',')

# %%
rate_hist = np.loadtxt('bitrate_record0.txt',delimiter=',')
time = rate_hist[:,0] - rate_hist[0,0]
plt.figure()
plt.plot(time, rate_hist[:,1], label='target_bitrate')
plt.plot(time, rate_hist[:,2], label='estimated throughput')
plt.grid()
